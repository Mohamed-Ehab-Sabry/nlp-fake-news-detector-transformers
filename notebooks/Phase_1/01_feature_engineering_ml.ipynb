# %% [markdown]
# import libraries

# %%
import sys
import importlib
import os
sys.path.append("../../src/features")  
import build_features
importlib.reload(build_features)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Lenovo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# ...

# %% [markdown]
# load clean data

# %%
df = build_features.load_clean_data("../../data/processed/processed.csv")
df
# Out:
#                                               cleaned_text  target
# 0        awww thats bummer shoulda got david carr third...       0
# 1        upset cant update facebook texting might cry r...       0
# 2        dived many times ball managed save rest go bounds       0
# 3                         whole body feels itchy like fire       0
# 4                             not behaving im mad cant see       0
# ...                                                    ...     ...
# 1482185                      woke school best feeling ever       1
# 1482186            thewdbcom cool hear old walt interviews       1
# 1482187                    ready mojo makeover ask details       1
# 1482188  happy th birthday boo alll time tupac amaru sh...       1
# 1482189                               happy charitytuesday       1
#
# [1482190 rows x 2 columns]

# %% [markdown]
# split data

# %%
X_train, X_val, X_test, y_train, y_val, y_test = build_features.split_data(df)

# %% [markdown]
# preprocess split

# %%
X_train, X_val, X_test = build_features.preprocess_split(X_train, X_val, X_test)

# %% [markdown]
# TF-IDF Vectorizer

# %%
X_train_tfidf, X_val_tfidf, X_test_tfidf, tfidf_vectorizer = build_features.build_tfidf_features(X_train, X_val, X_test)

# %% [markdown]
# save features

# %%
build_features.save_features(X_train_tfidf, X_val_tfidf, X_test_tfidf, y_train, y_val, y_test, tfidf_vectorizer)
# Out:
# TF-IDF vectorizer and feature matrices saved successfully
# X_train shape: (963423, 10000)
# X_val shape: (222329, 10000)
# X_test shape: (296438, 10000)

# %%
os.listdir("../../data/saved_features")
# Out:
# ['svd_model.joblib',
#  'tfidf_vectorizer.joblib',
#  'X_test_svd.joblib',
#  'X_test_tfidf.joblib',
#  'X_train_svd.joblib',
#  'X_train_tfidf.joblib',
#  'X_val_tfidf.joblib',
#  'y_test.joblib',
#  'y_train.joblib',
#  'y_val.joblib']

# %%
print("Shape of X_train_tfidf:", X_train_tfidf.shape)
print("Shape of X_test_tfidf:", X_test_tfidf.shape)
print("Shape of X_val_tfidf:", X_val_tfidf.shape)
# Out:
# Shape of X_train_tfidf: (963423, 10000)
# Shape of X_test_tfidf: (296438, 10000)
# Shape of X_val_tfidf: (222329, 10000)

# %%
# if you want to train models, load the saved features like this:

# from joblib import load
# X_train = load("../data/saved_features/X_train_tfidf.joblib")
# X_val = load("../data/saved_features/X_val_tfidf.joblib")
# X_test = load("../data/saved_features/X_test_tfidf.joblib")
# y_train = load("../data/saved_features/y_train.joblib")
# y_val = load("../data/saved_features/y_val.joblib")
# y_test = load("../data/saved_features/y_test.joblib")
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
